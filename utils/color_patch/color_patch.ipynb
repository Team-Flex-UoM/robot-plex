# %%
# imports
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

def imshowBGR(img,ax=plt):
    ax.imshow(cv.cvtColor(img,cv.COLOR_BGR2RGB))

# %%
im=cv.imread('M:\\Robotics\\Projects\SLRC\\robot-plex\src\\imgs\\0.png')
imshowBGR(im)

# %%
# !pwd
# Out:
# /m/Robotics/Projects/SLRC/robot-plex/utils/color_patch
